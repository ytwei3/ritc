# %% [markdown]
# ## Market Making
#
# 1. without speculation?

# %%
# %pip install -r "../requirements.txt"

# %%
import requests
from time import sleep

# %%
# Global variables
url = "http://localhost:9999/v1"
key = "test"

# %%
# %pip install scipy
